# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/MyDrive/authorship_anaysis/authorship_analysis/datasets
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/authorship_anaysis/authorship_analysis/datasets

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
print(module_path)
print(sys.path)
# Out:
# /content/gdrive/MyDrive/authorship_anaysis/authorship_analysis
# ['/content', '/env/python', '/usr/lib/python39.zip', '/usr/lib/python3.9', '/usr/lib/python3.9/lib-dynload', '', '/usr/local/lib/python3.9/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.9/dist-packages/IPython/extensions', '/root/.ipython', '/content/gdrive/MyDrive/authorship_anaysis/authorship_analysis']

# %%
! pip install -r ../requrements.txt
! pip install https://github.com/kpu/kenlm/archive/master.zip
! python -m spacy download pl_core_news_lg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached https://github.com/kpu/kenlm/archive/master.zip (553 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached https://github.com/kpu/kenlm/archive/master.zip (553 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# ...

# %%
from data_preparation import DataPreparation, authors_abbr
from data_fetchers import BookSet
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
preprocessing_list = ['anonymize', 'lower_text','POS_leave_only' ,'lemmatize_text', 'remove_punctuation']#'remove_stop_words', 'remove_punctuation', 'lemmatize_text']#, 'POS_leave_only']
pos = ['NOUN', 'VERB', 'ADJ']
#pos = []
prep_descr = 'set_alomp_NVAdj'
kinds_descr = 'e'
authors = ['Eliza Orzeszkowa', 'Henryk Sienkiewicz', 'Bolesław Prus']
#authors = ['Daniel Naborowski', 'Mikołaj Sęp Szarzyński', 'Elżbieta Drużbacka', 'Adam Mickiewicz', 'Juliusz Słowacki', 'Cyprian Kamil Norwid', 'Adam Asnyk', 'Maria Konopnicka', 'Kazimierz Przerwa-Tetmajer', 'Bolesław Leśmian', 'Jan Kasprowicz']
kinds = ['Epika']

# %%
bookset = BookSet()
bookset.fetch()

pozytywizm = bookset.list_of_books_to_author_title_list(bookset.get_books_by_authors_list_kinds(authors, kinds))
books_epoch_list = [pozytywizm]
print(books_epoch_list)
# Out:
# [[('Bolesław Prus', 'Antek'), ('Eliza Orzeszkowa', 'Australczyk'), ('Eliza Orzeszkowa', 'Autobiografia w listach'), ('Henryk Sienkiewicz', 'Bartek zwycięzca'), ('Henryk Sienkiewicz', 'Bez dogmatu'), ('Eliza Orzeszkowa', 'Cicho, cicho na leśnej polanie...'), ('Eliza Orzeszkowa', 'Cnotliwi'), ('Eliza Orzeszkowa', 'Co mówił stary klon?'), ('Eliza Orzeszkowa', 'Czy pamiętasz?'), ('Eliza Orzeszkowa', 'Dobra pani'), ('Eliza Orzeszkowa', 'Dwa bieguny'), ('Eliza Orzeszkowa', 'Dymy'), ('Eliza Orzeszkowa', 'Dziurdziowie'), ('Eliza Orzeszkowa', 'Šunadvokatis'), ('Bolesław Prus', 'Emancypantki'), ('Bolesław Prus', 'Emancypantki, tom pierwszy'), ('Bolesław Prus', 'Emancypantki, tom drugi'), ('Bolesław Prus', 'Faraon'), ('Bolesław Prus', 'Faraon, tom drugi'), ('Bolesław Prus', 'Faraon, tom pierwszy'), ('Bolesław Prus', 'Faraon, tom trzeci'), ('Eliza Orzeszkowa', 'Gdzie szczęście?'), ('Eliza Orzeszkowa', 'Gedali'), ('Eliza Orzeszkowa', 'Bóg wie kto'), ('Eliza Orzeszkowa', 'Dziwna historia'), ('Eliz
# ...

# %%
dp = DataPreparation(books_epoch_list)
dp.get_books()
dp.books_preprocessing(preprocessing_list, pos)
# Out:
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Bolesław Prus
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# Eliza Orzeszkowa
# ...

# %%
authors_a = authors_abbr(authors)
dir_path = prep_descr+'_'+kinds_descr+'_'+'_'.join(authors_a)
os.mkdir(dir_path)

# %%
for author in authors:
  os.mkdir(os.path.join(dir_path, author))
  book_number = 0
  for book in dp.books_text[author]:
    with open(os.path.join(dir_path, author, str(book_number)+'.txt'), 'w') as file:
      file.write(book)
    book_number += 1

# %%
a=['asdf', 'fd', 'ffffff']
with open('testttt', 'w') as f:
  for e in a:
    f.write(e + '\n')

# %%
with open('testttt', 'r') as f:
  a = f.readlines()
print([x[:-1] for x in a])

# %%
l = [[1,2]]
a=[4,5]
b=[]
l.append(a)

# %%
l

# %%
b.append(a)
b
